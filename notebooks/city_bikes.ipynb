# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import pandas as pd
import os

# %%
url = "http://api.citybik.es/"
href = "/v2/networks/"
response = requests.get(url + href)

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response into a Python dictionary
    data = response.json()
    print(data)
else:
    print("Request failed with status code:", response.status_code)
# Out:
# {'networks': [{'id': 'abu-dhabi-careem-bike', 'name': 'Abu Dhabi Careem BIKE', 'location': {'latitude': 24.4866, 'longitude': 54.3728, 'city': 'Abu Dhabi', 'country': 'AE'}, 'href': '/v2/networks/abu-dhabi-careem-bike', 'company': ['Careem'], 'gbfs_href': 'https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json'}, {'id': 'acces-velo-saguenay', 'name': 'Accès Vélo', 'location': {'latitude': 48.433333, 'longitude': -71.083333, 'city': 'Saguenay', 'country': 'CA'}, 'href': '/v2/networks/acces-velo-saguenay', 'company': ['PBSC Urban Solutions'], 'gbfs_href': 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json'}, {'id': 'aksu', 'name': 'Aksu', 'location': {'latitude': 41.1664, 'longitude': 80.2617, 'city': '阿克苏市 (Aksu City)', 'country': 'CN'}, 'href': '/v2/networks/aksu', 'company': ['阿克苏公共服务']}, {'id': 'alba', 'name': 'Alba', 'location': {'latitude': 44.716667, 'longitude': 8.083333, 'city': 'Alba', 'country': 'IT'}, 'href': '/v2/networks/alba', 'company': ['Comunicare S.r.l.'], 'system': 'Bicincittà', 'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=139'}, {'id': 'albabici', 'name': 'AlbaBici', 'location': {'latitude': 38.9943, 'longitude': -1.8602, 'city': 'Albacete', 'country': 'ES'}, 'href': '/v2/networks/albabici', 'company': ['Instituto Tecnológico de Castilla y León (ITCL)'], 'system': 'bicicard'}, {'id': 'algira', 'name': 'AlGira', 'location': {'latitude': 39.2082, 'longitude': -8.6252, 'city': 'Almeirim', 'country': 'PT'}, 'href': '/v2/networks/algira', 'company': ['Município de Almeirim', 'Wegoshare, Lda'], 'ebikes': True}, {'id': 'almatybike', 'name': 'Almatybike', 'location': {'latitude': 43.239101, 'longitude': 76.9268076, 'city': 'Almaty', 'country': 'KZ'}, 'href': '/v2/networks/almatybike', 'company': ['Velobike.kz, LLP', 'Smoove'], 'system': 'Velobike'}, {'id': 'alsa-nextbike-leon', 'name': 'Alsa nextbike León', 'location': {'latitude': 42.5987263, 'longitude': -5.5670959, 'city': 'León', 'country': 'ES'}, 'href': '/v2/networks/alsa-nextbike-leon', 'company': ['Leonbici Nextbike Gmbh Y Autobuses Urbanos De Leon S.a. Ute'], 'system': 'Nextbike'}, {'id': 'ambici-badalona', 'name': 'Ambici', 'location': {'latitude': 41.447, 'longitude': 2.245, 'city': 'Badalona', 'country': 'ES'}, 'href': '/v2/networks/ambici-badalona', 'company': ['Nextbike GmbH', 'TIER Mobility SE', 'Transports Metropolitans de Barcelona', 'Projectes i Serveis de Mobilitat S.A'], 'system': 'Ambici'}, {'id': 'ambici-castelldefels', 'name': 'Ambici', 'location': {'latitude': 41.2816, 'longitude': 1.97678, 'city': 'Castelldefels', 'country': 'ES'}, 'href': '/v2/networks/ambici-castelldefels', 'company': ['Nextbike GmbH', 'TIER Mobility SE', 'Transports Metropolitans de Barcelona', 'Projectes i Serveis de Mobilitat S.A'], 'system': 'Ambici'}, {'id': 'ambici-cornella-de-llobregat', 'name': 'Ambici', 'location': {'latitude': 41.3585, 'longitude': 2.07081, 'city': 'Cornellà de Llobregat', 'country': 'ES'}, 'href': '/v2/networks/ambici-cornella-de-llobregat', 'company': ['Nextbike GmbH', 'TIER Mobility SE', 'Transports Metropolitans de Barcelona', 'Projectes i Serveis de Mobilitat S.A'], 'system': 'Ambici'}, {'id': 'ambici-el-prat-de-llobregat', 'name': 'Ambici', 'location': {'latitude': 41.3239, 'longitude': 2.09317, 'city': 'El Prat de Llobregat', 'country': 'ES'}, 'href': '/v2/networks/ambici-el-prat-de-llobregat', 'company': ['Nextbike GmbH', 'TIER Mobility SE', 'Transports Metropolitans de Barcelona', 'Projectes i Serveis de Mobilitat S.A'], 'system': 'Ambici'}, {'id': 'ambici-esplugues-de-llobregat', 'name': 'Ambici', 'location': {'latitude': 41.3771, 'longitude': 2.08938, 'city': 'Esplugues de Llobregat', 'country': 'ES'}, 'href': '/v2/networks/ambici-esplugues-de-llobregat', 'company': ['Nextbike GmbH', 'TIER Mobility SE', 'Transports Metropolitans de Barcelona', 'Projectes i Serveis de Mobilitat S.A'], 'system': 'Ambici'}, {'id': 'ambici-gava', 'name': 'Ambici', 'location': {'latitude': 41.303, 'longitude': 2.00269 ...

# %%
networks = data['networks']
city = 'Vancouver'

# %%
#Getting the vancouver network from the citybikes json request
filtered_network = [network for network in networks if network['location']['city'] == city]
print(filtered_network)
# Out:
# [{'id': 'mobibikes', 'name': 'Mobi', 'location': {'latitude': 49.2827, 'longitude': -123.1207, 'city': 'Vancouver', 'country': 'CA'}, 'href': '/v2/networks/mobibikes', 'company': ['Vanncouver Bike Share Inc.', 'CycleHop LLC', 'City of Vancouver', 'Shaw Communications Inc.', 'Fifteen'], 'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json'}]

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
#printing a test L & L
print('Longitude: ' + str(filtered_network[0]['location']['longitude']))
print('Latitude: ' + str(filtered_network[0]['location']['latitude']))
# Out:
# Longitude: -123.1207
# Latitude: 49.2827

# %%
network_id = filtered_network[0]['href']
network_id
# Out:
# '/v2/networks/mobibikes'

# %%
#add the specific vancouver network id to the URL for the get request
url = "http://api.citybik.es"
id = network_id
response1 = requests.get(url + id)

# %%
if response1.status_code == 200:
    # Parse the JSON response into a Python dictionary
    data1 = response1.json()
    print(data1)  # Print the JSON structure to check it

    # Normalize the 'stations' data under the 'network'
    try:
        van_network_stations = pd.json_normalize(data=data1, record_path=['network', 'stations'])

        # Select only the columns you're interested in
        van_network_stations = van_network_stations[['free_bikes', 'id', 'longitude', 'latitude']]

        # Display the DataFrame to check the result
        print(van_network_stations)

    except KeyError as e:
        print(f"KeyError: {e} - Please check the JSON structure for the correct keys.")
    except TypeError as e:
        print(f"TypeError: {e} - This might be related to an unexpected data type in the JSON.")

else:
    print("Request failed with status code:", response1.status_code)
# Out:
# {'network': {'id': 'mobibikes', 'name': 'Mobi', 'location': {'latitude': 49.2827, 'longitude': -123.1207, 'city': 'Vancouver', 'country': 'CA'}, 'href': '/v2/networks/mobibikes', 'company': ['Vanncouver Bike Share Inc.', 'CycleHop LLC', 'City of Vancouver', 'Shaw Communications Inc.', 'Fifteen'], 'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json', 'stations': [{'id': '00fa94ad698dc4a9e4d708d6fd32f294', 'name': 'Chilco & Barclay', 'latitude': 49.291909, 'longitude': -123.140713, 'timestamp': '2024-09-23T13:27:35.140609Z', 'free_bikes': 10, 'empty_slots': 7, 'extra': {'uid': '0092', 'renting': True, 'returning': True, 'last_updated': 1727097811, 'slots': 18, 'normal_bikes': 10, 'ebikes': 0, 'has_ebikes': True}}, {'id': '012d3e06901cc222b1c2cf0a2ace3a29', 'name': 'St George & Broadway', 'latitude': 49.262321, 'longitude': -123.09306, 'timestamp': '2024-09-23T13:27:35.206853Z', 'free_bikes': 7, 'empty_slots': 5, 'extra': {'uid': '0248', 'renting': True, 'returning': True, 'last_updated': 1727097899, 'slots': 14, 'normal_bikes': 5, 'ebikes': 2, 'has_ebikes': True}}, {'id': '029a505bd4422a1afd127987757f71a6', 'name': 'Britannia Parking Lot', 'latitude': 49.275882, 'longitude': -123.071865, 'timestamp': '2024-09-23T13:27:35.181798Z', 'free_bikes': 4, 'empty_slots': 10, 'extra': {'uid': '0232', 'renting': True, 'returning': True, 'last_updated': 1727097407, 'slots': 14, 'normal_bikes': 4, 'ebikes': 0, 'has_ebikes': True}}, {'id': '0438114d2e6b96118de69bc9775bb21e', 'name': 'Morton & Denman', 'latitude': 49.28803, 'longitude': -123.142135, 'timestamp': '2024-09-23T13:27:35.130037Z', 'free_bikes': 17, 'empty_slots': 9, 'extra': {'uid': '0031', 'renting': True, 'returning': True, 'last_updated': 1727097632, 'slots': 26, 'normal_bikes': 16, 'ebikes': 1, 'has_ebikes': True}}, {'id': '0459b7e93703980b853cd65a9dc60596', 'name': 'Thornton & National', 'latitude': 49.273777, 'longitude': -123.092723, 'timestamp': '2024-09-23T13:27:35.181909Z', 'free_bikes': 6, 'empty_slots': 8, 'extra': {'uid': '0233', 'renting': True, 'returning': True, 'last_updated': 1727097163, 'slots': 14, 'normal_bikes': 4, 'ebikes': 2, 'has_ebikes': True}}, {'id': '04f64fde5ba1ebde8ad78c74914adb34', 'name': 'Burrard & 14th', 'latitude': 49.259469, 'longitude': -123.145718, 'timestamp': '2024-09-23T13:27:35.161950Z', 'free_bikes': 14, 'empty_slots': 3, 'extra': {'uid': '0210', 'renting': True, 'returning': True, 'last_updated': 1727097923, 'slots': 18, 'normal_bikes': 2, 'ebikes': 12, 'has_ebikes': True}}, {'id': '06487275cd19694152824c7c3088e8ff', 'name': 'Olympic Village Station', 'latitude': 49.266314, 'longitude': -123.116011, 'timestamp': '2024-09-23T13:27:35.128303Z', 'free_bikes': 17, 'empty_slots': 8, 'extra': {'uid': '0006', 'renting': True, 'returning': True, 'last_updated': 1727097683, 'slots': 26, 'normal_bikes': 17, 'ebikes': 0, 'has_ebikes': True}}, {'id': '064a7b39b1dbc4bfc4cf8f454e360c57', 'name': '8th & Macdonald', 'latitude': 49.264928, 'longitude': -123.168068, 'timestamp': '2024-09-23T13:27:35.235705Z', 'free_bikes': 15, 'empty_slots': 6, 'extra': {'uid': '0452', 'renting': True, 'returning': True, 'last_updated': 1727097882, 'slots': 22, 'normal_bikes': 12, 'ebikes': 3, 'has_ebikes': True}}, {'id': '066ecc3584913fa035ec1417323beb80', 'name': '30th & Ontario', 'latitude': 49.243375, 'longitude': -123.104978, 'timestamp': '2024-09-23T13:27:35.257313Z', 'free_bikes': 0, 'empty_slots': 21, 'extra': {'uid': '0557', 'renting': True, 'returning': True, 'last_updated': 1727097975, 'slots': 22, 'normal_bikes': 0, 'ebikes': 0, 'has_ebikes': True}}, {'id': '06bdc4d55f34b2a491305534fd5defda', 'name': 'Lakewood & Triumph', 'latitude': 49.283968, 'longitude': -123.061615, 'timestamp': '2024-09-23T13:27:35.603411Z', 'free_bikes': 7, 'empty_slots': 8, 'extra': {'uid': '0631', 'renting': True, 'returning': True, 'last_updated': 1727097930, 'slots': 16, 'normal_bikes': 1, 'ebikes': 6, 'has_ebikes': True}}, {'id': '07b13214cb69f2ec007d888450f3d6bc', 'nam ...
#      free_bikes                                id   longitude   latitude
# 0            10  00fa94ad698dc4a9e4d708d6fd32f294 -123.140713  49.291909
# 1             7  012d3e06901cc222b1c2cf0a2ace3a29 -123.093060  49.262321
# 2             4  029a505bd4422a1afd127987757f71a6 -123.071865  49.275882
# 3            17  0438114d2e6b96118de69bc9775bb21e -123.142135  49.288030
# 4             6  0459b7e93703980b853cd65a9dc60596 -123.092723  49.273777
# ..          ...                               ...         ...        ...
# 251          11  fbb4c06b719596c21f91fd51ef6d4710 -123.119425  49.265089
# 252          12  fe0c57d04d6e682d284d501446095fc9 -123.095830  49.277595
# 253          10  fedff7a263c182df94bda7307059cc52 -123.122589  49.277141
# 254          25  fef69fb400210d861107a61db954d037 -123.108020  49.279821
# 255           4  fffd87607aaae16fbb1f71615cbe7d17 -123.095680  49.263518
#
# [256 rows x 4 columns]

# %%
data1
# Out:
# {'network': {'id': 'mobibikes',
#   'name': 'Mobi',
#   'location': {'latitude': 49.2827,
#    'longitude': -123.1207,
#    'city': 'Vancouver',
#    'country': 'CA'},
#   'href': '/v2/networks/mobibikes',
#   'company': ['Vanncouver Bike Share Inc.',
#    'CycleHop LLC',
#    'City of Vancouver',
#    'Shaw Communications Inc.',
#    'Fifteen'],
#   'gbfs_href': 'https://vancouver-gbfs.smoove.pro/gbfs/2/gbfs.json',
#   'stations': [{'id': '00fa94ad698dc4a9e4d708d6fd32f294',
#     'name': 'Chilco & Barclay',
#     'latitude': 49.291909,
#     'longitude': -123.140713,
#     'timestamp': '2024-09-23T13:27:35.140609Z',
#     'free_bikes': 10,
#     'empty_slots': 7,
#     'extra': {'uid': '0092',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097811,
#      'slots': 18,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '012d3e06901cc222b1c2cf0a2ace3a29',
#     'name': 'St George & Broadway',
#     'latitude': 49.262321,
#     'longitude': -123.09306,
#     'timestamp': '2024-09-23T13:27:35.206853Z',
#     'free_bikes': 7,
#     'empty_slots': 5,
#     'extra': {'uid': '0248',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097899,
#      'slots': 14,
#      'normal_bikes': 5,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '029a505bd4422a1afd127987757f71a6',
#     'name': 'Britannia Parking Lot',
#     'latitude': 49.275882,
#     'longitude': -123.071865,
#     'timestamp': '2024-09-23T13:27:35.181798Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0232',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097407,
#      'slots': 14,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '0438114d2e6b96118de69bc9775bb21e',
#     'name': 'Morton & Denman',
#     'latitude': 49.28803,
#     'longitude': -123.142135,
#     'timestamp': '2024-09-23T13:27:35.130037Z',
#     'free_bikes': 17,
#     'empty_slots': 9,
#     'extra': {'uid': '0031',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097632,
#      'slots': 26,
#      'normal_bikes': 16,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '0459b7e93703980b853cd65a9dc60596',
#     'name': 'Thornton & National',
#     'latitude': 49.273777,
#     'longitude': -123.092723,
#     'timestamp': '2024-09-23T13:27:35.181909Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '0233',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097163,
#      'slots': 14,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '04f64fde5ba1ebde8ad78c74914adb34',
#     'name': 'Burrard & 14th',
#     'latitude': 49.259469,
#     'longitude': -123.145718,
#     'timestamp': '2024-09-23T13:27:35.161950Z',
#     'free_bikes': 14,
#     'empty_slots': 3,
#     'extra': {'uid': '0210',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097923,
#      'slots': 18,
#      'normal_bikes': 2,
#      'ebikes': 12,
#      'has_ebikes': True}},
#    {'id': '06487275cd19694152824c7c3088e8ff',
#     'name': 'Olympic Village Station',
#     'latitude': 49.266314,
#     'longitude': -123.116011,
#     'timestamp': '2024-09-23T13:27:35.128303Z',
#     'free_bikes': 17,
#     'empty_slots': 8,
#     'extra': {'uid': '0006',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097683,
#      'slots': 26,
#      'normal_bikes': 17,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '064a7b39b1dbc4bfc4cf8f454e360c57',
#     'name': '8th & Macdonald',
#     'latitude': 49.264928,
#     'longitude': -123.168068,
#     'timestamp': '2024-09-23T13:27:35.235705Z',
#     'free_bikes': 15,
#     'empty_slots': 6,
#     'extra': {'uid': '0452',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097882,
#      'slots': 22,
#      'normal_bikes': 12,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '066ecc3584913fa035ec1417323beb80',
#     'name': '30th & Ontario',
#     'latitude': 49.243375,
#     'longitude': -123.104978,
#     'timestamp': '2024-09-23T13:27:35.257313Z',
#     'free_bikes': 0,
#     'empty_slots': 21,
#     'extra': {'uid': '0557',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097975,
#      'slots': 22,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '06bdc4d55f34b2a491305534fd5defda',
#     'name': 'Lakewood & Triumph',
#     'latitude': 49.283968,
#     'longitude': -123.061615,
#     'timestamp': '2024-09-23T13:27:35.603411Z',
#     'free_bikes': 7,
#     'empty_slots': 8,
#     'extra': {'uid': '0631',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097930,
#      'slots': 16,
#      'normal_bikes': 1,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': '07b13214cb69f2ec007d888450f3d6bc',
#     'name': '13th & Cambie',
#     'latitude': 49.259579,
#     'longitude': -123.114769,
#     'timestamp': '2024-09-23T13:27:35.234692Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0311',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097989,
#      'slots': 14,
#      'normal_bikes': 2,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '085a0e120a08a80a58c0ae0ff9da565a',
#     'name': 'Arbutus & Nanton',
#     'latitude': 49.247854,
#     'longitude': -123.153422,
#     'timestamp': '2024-09-23T13:27:35.250389Z',
#     'free_bikes': 5,
#     'empty_slots': 13,
#     'extra': {'uid': '0480',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097637,
#      'slots': 18,
#      'normal_bikes': 4,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '08c7a90bf297fde8c1f1156db13987d4',
#     'name': '14th & Fraser',
#     'latitude': 49.257939,
#     'longitude': -123.089531,
#     'timestamp': '2024-09-23T13:27:35.234026Z',
#     'free_bikes': 3,
#     'empty_slots': 13,
#     'extra': {'uid': '0282',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097812,
#      'slots': 16,
#      'normal_bikes': 2,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '0a43242bee10cd33f539af2c1bf5ecbf',
#     'name': '15th & Victoria (Trout Lake)',
#     'latitude': 49.256857,
#     'longitude': -123.065646,
#     'timestamp': '2024-09-23T13:27:35.233811Z',
#     'free_bikes': 7,
#     'empty_slots': 10,
#     'extra': {'uid': '0278',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097056,
#      'slots': 18,
#      'normal_bikes': 6,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '0b543fc4e694fe07a54dac48bb1b3390',
#     'name': 'Robson & Hornby',
#     'latitude': 49.282758,
#     'longitude': -123.122092,
#     'timestamp': '2024-09-23T13:27:35.129383Z',
#     'free_bikes': 6,
#     'empty_slots': 23,
#     'extra': {'uid': '0019',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727093224,
#      'slots': 30,
#      'normal_bikes': 5,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '0c42f45e4a14957ad4a6d521d0ba8bc3',
#     'name': 'Cardero & Robson',
#     'latitude': 49.289255,
#     'longitude': -123.132677,
#     'timestamp': '2024-09-23T13:27:35.130663Z',
#     'free_bikes': 15,
#     'empty_slots': 10,
#     'extra': {'uid': '0041',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097992,
#      'slots': 26,
#      'normal_bikes': 13,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '0c9ad3e3703e5869b82619ecdf54f43e',
#     'name': '1st & Scotia',
#     'latitude': 49.2685027,
#     'longitude': -123.0975014,
#     'timestamp': '2024-09-23T13:27:35.160988Z',
#     'free_bikes': 13,
#     'empty_slots': 7,
#     'extra': {'uid': '0197',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097812,
#      'slots': 20,
#      'normal_bikes': 13,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '0cee06d7d10f7d3162cea03d22b7beed',
#     'name': '10th & Fraser',
#     'latitude': 49.26151,
#     'longitude': -123.089413,
#     'timestamp': '2024-09-23T13:27:35.232853Z',
#     'free_bikes': 4,
#     'empty_slots': 8,
#     'extra': {'uid': '0260',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097809,
#      'slots': 14,
#      'normal_bikes': 0,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': '0cf6cd1809fa7f510812f5b052f578c4',
#     'name': 'Ontario & 5th',
#     'latitude': 49.266724,
#     'longitude': -123.104824,
#     'timestamp': '2024-09-23T13:27:35.131875Z',
#     'free_bikes': 11,
#     'empty_slots': 9,
#     'extra': {'uid': '0073',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097922,
#      'slots': 20,
#      'normal_bikes': 10,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '0d1b5c62f8d22e3650811df55596e25b',
#     'name': 'Heather & 16th',
#     'latitude': 49.256845,
#     'longitude': -123.120071,
#     'timestamp': '2024-09-23T13:27:35.142580Z',
#     'free_bikes': 1,
#     'empty_slots': 9,
#     'extra': {'uid': '0130',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097672,
#      'slots': 12,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '0e0aef6fabaa808b3a3cef24657257a4',
#     'name': 'Richards & Smithe',
#     'latitude': 49.279259,
#     'longitude': -123.119145,
#     'timestamp': '2024-09-23T13:27:35.131347Z',
#     'free_bikes': 7,
#     'empty_slots': 10,
#     'extra': {'uid': '0058',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097790,
#      'slots': 18,
#      'normal_bikes': 5,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '10acadd77bc21f26a7f09d8c74d4af2d',
#     'name': 'Robson & Beatty',
#     'latitude': 49.277773,
#     'longitude': -123.114237,
#     'timestamp': '2024-09-23T13:27:35.129674Z',
#     'free_bikes': 10,
#     'empty_slots': 11,
#     'extra': {'uid': '0026',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097521,
#      'slots': 21,
#      'normal_bikes': 6,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': '12dd264419c06f596d1a883ed36efd9c',
#     'name': 'Maple Tree Square',
#     'latitude': 49.283482,
#     'longitude': -123.103738,
#     'timestamp': '2024-09-23T13:27:35.128824Z',
#     'free_bikes': 11,
#     'empty_slots': 13,
#     'extra': {'uid': '0013',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097918,
#      'slots': 25,
#      'normal_bikes': 9,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '13021bba7bbeca1ccd8726ca17da59e6',
#     'name': '22nd & Main',
#     'latitude': 49.25094,
#     'longitude': -123.101306,
#     'timestamp': '2024-09-23T13:27:35.602972Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '0563',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097754,
#      'slots': 14,
#      'normal_bikes': 5,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '1648ead5ea617d2cea115869d9516f5e',
#     'name': 'Carrall & Seawall',
#     'latitude': 49.276294,
#     'longitude': -123.106534,
#     'timestamp': '2024-09-23T13:27:35.162337Z',
#     'free_bikes': 3,
#     'empty_slots': 14,
#     'extra': {'uid': '0218',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097716,
#      'slots': 18,
#      'normal_bikes': 2,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '1675a77b9af656faf527b4e6de53e63b',
#     'name': 'Charles & Woodland',
#     'latitude': 49.2731,
#     'longitude': -123.0732,
#     'timestamp': '2024-09-23T13:27:35.232419Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '0253',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097460,
#      'slots': 14,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '175a074bf65455d1633639511dc129c8',
#     'name': '1st & Manitoba',
#     'latitude': 49.27023,
#     'longitude': -123.10651,
#     'timestamp': '2024-09-23T13:27:35.144682Z',
#     'free_bikes': 27,
#     'empty_slots': 0,
#     'extra': {'uid': '0174',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097943,
#      'slots': 28,
#      'normal_bikes': 5,
#      'ebikes': 22,
#      'has_ebikes': True}},
#    {'id': '17a3320a52bcc62161908967f8a06613',
#     'name': 'St Catherines & 7th',
#     'latitude': 49.264466,
#     'longitude': -123.085183,
#     'timestamp': '2024-09-23T13:27:35.233135Z',
#     'free_bikes': 15,
#     'empty_slots': 3,
#     'extra': {'uid': '0266',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097765,
#      'slots': 20,
#      'normal_bikes': 14,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '198810b9b0af5d229d1b6fa12c620e06',
#     'name': 'Triumph & Victoria',
#     'latitude': 49.283986,
#     'longitude': -123.065264,
#     'timestamp': '2024-09-23T13:27:35.233888Z',
#     'free_bikes': 2,
#     'empty_slots': 16,
#     'extra': {'uid': '0280',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097778,
#      'slots': 18,
#      'normal_bikes': 2,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '1bca0e944a4faf170db82793414b03ab',
#     'name': '18th & Main',
#     'latitude': 49.254667,
#     'longitude': -123.101389,
#     'timestamp': '2024-09-23T13:27:35.232568Z',
#     'free_bikes': 2,
#     'empty_slots': 14,
#     'extra': {'uid': '0255',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097909,
#      'slots': 16,
#      'normal_bikes': 2,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '1c8f7fd6535db12cc45cfc59aa9da058',
#     'name': 'St Catherines & 10th',
#     'latitude': 49.261353,
#     'longitude': -123.085333,
#     'timestamp': '2024-09-23T13:27:35.233064Z',
#     'free_bikes': 0,
#     'empty_slots': 12,
#     'extra': {'uid': '0265',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097668,
#      'slots': 12,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '1d4153659a0a0a2089078c739df6737d',
#     'name': 'Nelson & Richards',
#     'latitude': 49.277844,
#     'longitude': -123.120942,
#     'timestamp': '2024-09-23T13:27:35.132283Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0079',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097951,
#      'slots': 18,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '1d442ad1a71774c82688a45954e47bfd',
#     'name': 'Arbutus & 10th',
#     'latitude': 49.262835,
#     'longitude': -123.152626,
#     'timestamp': '2024-09-23T13:27:35.131944Z',
#     'free_bikes': 9,
#     'empty_slots': 9,
#     'extra': {'uid': '0075',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097800,
#      'slots': 18,
#      'normal_bikes': 6,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '1d7e73b3321ebb6713774d376247d9f9',
#     'name': 'Comox & Denman',
#     'latitude': 49.288444,
#     'longitude': -123.139203,
#     'timestamp': '2024-09-23T13:27:35.130107Z',
#     'free_bikes': 2,
#     'empty_slots': 16,
#     'extra': {'uid': '0032',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097911,
#      'slots': 18,
#      'normal_bikes': 2,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '1ef01f2f89621d51afbabaa6296e55be',
#     'name': 'Prince Edward & 14th',
#     'latitude': 49.258352,
#     'longitude': -123.096337,
#     'timestamp': '2024-09-23T13:27:35.232711Z',
#     'free_bikes': 5,
#     'empty_slots': 7,
#     'extra': {'uid': '0257',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097657,
#      'slots': 14,
#      'normal_bikes': 4,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '1ef5c4ff3f0b09422bb1597fd9d7568b',
#     'name': 'Alexander & Railway',
#     'latitude': 49.283992,
#     'longitude': -123.091206,
#     'timestamp': '2024-09-23T13:27:35.181642Z',
#     'free_bikes': 12,
#     'empty_slots': 8,
#     'extra': {'uid': '0230',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097479,
#      'slots': 20,
#      'normal_bikes': 8,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': '25318ec3e06fae1397a3a2f645104149',
#     'name': 'Chilco & Beach',
#     'latitude': 49.28972,
#     'longitude': -123.144028,
#     'timestamp': '2024-09-23T13:27:35.130880Z',
#     'free_bikes': 13,
#     'empty_slots': 1,
#     'extra': {'uid': '0047',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097822,
#      'slots': 14,
#      'normal_bikes': 13,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '257715b845828e027ff35dd0f11c971e',
#     'name': 'Richards & Cordova',
#     'latitude': 49.284554,
#     'longitude': -123.111031,
#     'timestamp': '2024-09-23T13:27:35.142359Z',
#     'free_bikes': 12,
#     'empty_slots': 3,
#     'extra': {'uid': '0124',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097983,
#      'slots': 16,
#      'normal_bikes': 10,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '261efc67071963969b3f848c66454d97',
#     'name': 'Orchard Commons',
#     'latitude': 49.259999,
#     'longitude': -123.250902,
#     'timestamp': '2024-09-23T13:27:35.604220Z',
#     'free_bikes': 4,
#     'empty_slots': 21,
#     'extra': {'uid': '2116',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097646,
#      'slots': 26,
#      'normal_bikes': 2,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '2681455ba2d97283998a806b14d3e95c',
#     'name': 'Yew & Broadway',
#     'latitude': 49.263523,
#     'longitude': -123.155267,
#     'timestamp': '2024-09-23T13:27:35.250832Z',
#     'free_bikes': 4,
#     'empty_slots': 13,
#     'extra': {'uid': '0484',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097537,
#      'slots': 18,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '277b4b4881bdb7dac73012672179def8',
#     'name': 'Woodland & 10th',
#     'latitude': 49.261263,
#     'longitude': -123.073707,
#     'timestamp': '2024-09-23T13:27:35.206723Z',
#     'free_bikes': 8,
#     'empty_slots': 6,
#     'extra': {'uid': '0245',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097804,
#      'slots': 14,
#      'normal_bikes': 7,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '2781435bde344e1b64f1bebac6bc9008',
#     'name': 'Ontario & 16th',
#     'latitude': 49.256825,
#     'longitude': -123.105234,
#     'timestamp': '2024-09-23T13:27:35.142722Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0133',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097910,
#      'slots': 14,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '2ca388bba54706770900ca2a9d7aa5be',
#     'name': '14th & Alder',
#     'latitude': 49.258819,
#     'longitude': -123.131317,
#     'timestamp': '2024-09-23T13:27:35.162014Z',
#     'free_bikes': 3,
#     'empty_slots': 10,
#     'extra': {'uid': '0211',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097992,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '2f09a64507cf6257c67ca20af27339eb',
#     'name': 'Chestnut & McNicoll',
#     'latitude': 49.275938,
#     'longitude': -123.145939,
#     'timestamp': '2024-09-23T13:27:35.143436Z',
#     'free_bikes': 4,
#     'empty_slots': 11,
#     'extra': {'uid': '0147',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097778,
#      'slots': 16,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '2ff7eb4230654603592ab1b0780ec5e1',
#     'name': 'Dunbar & 6th',
#     'latitude': 49.266636,
#     'longitude': -123.183661,
#     'timestamp': '2024-09-23T13:27:35.235301Z',
#     'free_bikes': 2,
#     'empty_slots': 14,
#     'extra': {'uid': '0414',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097821,
#      'slots': 16,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '30bf49544b1c864688b78172d42cca5e',
#     'name': 'Stanley Park - Vancouver Aquarium',
#     'latitude': 49.299292,
#     'longitude': -123.130281,
#     'timestamp': '2024-09-23T13:27:35.140974Z',
#     'free_bikes': 6,
#     'empty_slots': 10,
#     'extra': {'uid': '0101',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097827,
#      'slots': 17,
#      'normal_bikes': 6,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '32603a87cfca71d0f7dfa3513bad69d5',
#     'name': 'Yaletown-Roundhouse Station',
#     'latitude': 49.274566,
#     'longitude': -123.121817,
#     'timestamp': '2024-09-23T13:27:35.128145Z',
#     'free_bikes': 11,
#     'empty_slots': 4,
#     'extra': {'uid': '0004',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097898,
#      'slots': 16,
#      'normal_bikes': 9,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '32f70f7ae14ba87523c6286a6c4d5c37',
#     'name': 'Smithe & Burrard',
#     'latitude': 49.282503,
#     'longitude': -123.124697,
#     'timestamp': '2024-09-23T13:27:35.162273Z',
#     'free_bikes': 11,
#     'empty_slots': 4,
#     'extra': {'uid': '0217',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097933,
#      'slots': 18,
#      'normal_bikes': 5,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': '3367c1e1dbf73caf7c10e4c96a92f58d',
#     'name': 'Abbott & Cordova',
#     'latitude': 49.282759,
#     'longitude': -123.106955,
#     'timestamp': '2024-09-23T13:27:35.129969Z',
#     'free_bikes': 17,
#     'empty_slots': 5,
#     'extra': {'uid': '0030',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097668,
#      'slots': 22,
#      'normal_bikes': 15,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '34fd37d12eb989b49518ef53941ee3ff',
#     'name': 'Sasamat & 10th',
#     'latitude': 49.264019,
#     'longitude': -123.209176,
#     'timestamp': '2024-09-23T13:27:35.603958Z',
#     'free_bikes': 3,
#     'empty_slots': 18,
#     'extra': {'uid': '0716',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097398,
#      'slots': 22,
#      'normal_bikes': 3,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '3596b4831ee2ea7812de753b32306835',
#     'name': 'Vine & 4th',
#     'latitude': 49.268339,
#     'longitude': -123.157443,
#     'timestamp': '2024-09-23T13:27:35.144000Z',
#     'free_bikes': 6,
#     'empty_slots': 12,
#     'extra': {'uid': '0159',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097911,
#      'slots': 18,
#      'normal_bikes': 1,
#      'ebikes': 5,
#      'has_ebikes': True}},
#    {'id': '35eb539fb9298bb7e4f6759ca0256505',
#     'name': '10th & Ontario',
#     'latitude': 49.262062,
#     'longitude': -123.104656,
#     'timestamp': '2024-09-23T13:27:35.144755Z',
#     'free_bikes': 4,
#     'empty_slots': 16,
#     'extra': {'uid': '0176',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097862,
#      'slots': 20,
#      'normal_bikes': 1,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '365da33e9ce06ea53db1173a0f8eae71',
#     'name': 'Pine & 10th',
#     'latitude': 49.262822,
#     'longitude': -123.14338,
#     'timestamp': '2024-09-23T13:27:35.161690Z',
#     'free_bikes': 6,
#     'empty_slots': 14,
#     'extra': {'uid': '0205',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097733,
#      'slots': 20,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '38f045e3f43f86eae42ca4c60257ade0',
#     'name': 'Wallace & 4th',
#     'latitude': 49.268974,
#     'longitude': -123.190701,
#     'timestamp': '2024-09-23T13:27:35.235126Z',
#     'free_bikes': 14,
#     'empty_slots': 4,
#     'extra': {'uid': '0401',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097839,
#      'slots': 18,
#      'normal_bikes': 14,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '3a4131fa94946d93d3529136efd62413',
#     'name': 'Pacific & Richards',
#     'latitude': 49.273663,
#     'longitude': -123.127075,
#     'timestamp': '2024-09-23T13:27:35.130737Z',
#     'free_bikes': 12,
#     'empty_slots': 1,
#     'extra': {'uid': '0044',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097958,
#      'slots': 14,
#      'normal_bikes': 12,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '3aed670ccdcd94b966c0f505f8b028c7',
#     'name': '7th &  Alder',
#     'latitude': 49.265198,
#     'longitude': -123.131043,
#     'timestamp': '2024-09-23T13:27:35.145406Z',
#     'free_bikes': 3,
#     'empty_slots': 10,
#     'extra': {'uid': '0192',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097481,
#      'slots': 16,
#      'normal_bikes': 1,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '3e112f9fe877e0003780386359060ae6',
#     'name': 'Canada Place',
#     'latitude': 49.287214,
#     'longitude': -123.11287,
#     'timestamp': '2024-09-23T13:27:35.128897Z',
#     'free_bikes': 19,
#     'empty_slots': 5,
#     'extra': {'uid': '0014',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097843,
#      'slots': 26,
#      'normal_bikes': 14,
#      'ebikes': 5,
#      'has_ebikes': True}},
#    {'id': '41a55a7e2908fbbd65175b794d26bc8d',
#     'name': 'Heather & 18th',
#     'latitude': 49.255034,
#     'longitude': -123.120226,
#     'timestamp': '2024-09-23T13:27:35.251803Z',
#     'free_bikes': 5,
#     'empty_slots': 10,
#     'extra': {'uid': '0511',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097981,
#      'slots': 16,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '421516af381a11f54d07fc79be68d3d3',
#     'name': '14th & Oak',
#     'latitude': 49.258761,
#     'longitude': -123.127071,
#     'timestamp': '2024-09-23T13:27:35.161546Z',
#     'free_bikes': 3,
#     'empty_slots': 11,
#     'extra': {'uid': '0202',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097521,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '434b6f4e7fc30198f901b60fc905f609',
#     'name': 'Bute & Comox',
#     'latitude': 49.283343,
#     'longitude': -123.131099,
#     'timestamp': '2024-09-23T13:27:35.131028Z',
#     'free_bikes': 2,
#     'empty_slots': 22,
#     'extra': {'uid': '0050',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727083167,
#      'slots': 22,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '444991edc9550be0908f032da5e3c95f',
#     'name': 'Comox & Broughton',
#     'latitude': 49.285253,
#     'longitude': -123.134356,
#     'timestamp': '2024-09-23T13:27:35.130954Z',
#     'free_bikes': 5,
#     'empty_slots': 5,
#     'extra': {'uid': '0048',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097573,
#      'slots': 12,
#      'normal_bikes': 2,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '44fc3d58831a9f2b919c7a3a1838b74a',
#     'name': 'Station & Terminal',
#     'latitude': 49.272172,
#     'longitude': -123.097978,
#     'timestamp': '2024-09-23T13:27:35.235007Z',
#     'free_bikes': 6,
#     'empty_slots': 10,
#     'extra': {'uid': '0354',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097419,
#      'slots': 18,
#      'normal_bikes': 5,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '45a4c865db23e1cad0209afa5a799de0',
#     'name': 'Stanley Park - Third Beach Parking Lot',
#     'latitude': 49.302577,
#     'longitude': -123.155616,
#     'timestamp': '2024-09-23T13:27:35.141123Z',
#     'free_bikes': 12,
#     'empty_slots': 26,
#     'extra': {'uid': '0103',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097888,
#      'slots': 38,
#      'normal_bikes': 12,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '475627e149c1a6ba73caac8d8d2fa617',
#     'name': 'Woodland & 4th',
#     'latitude': 49.266751,
#     'longitude': -123.073501,
#     'timestamp': '2024-09-23T13:27:35.232260Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0250',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097943,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '485d4d24c803cfde829ab89699fed833',
#     'name': '8th & Ash',
#     'latitude': 49.264215,
#     'longitude': -123.117772,
#     'timestamp': '2024-09-23T13:27:35.128453Z',
#     'free_bikes': 5,
#     'empty_slots': 9,
#     'extra': {'uid': '0008',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727096916,
#      'slots': 16,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '4990fe5772f3b73eebeec125b41e478e',
#     'name': 'Burrard & Drake',
#     'latitude': 49.27808,
#     'longitude': -123.130557,
#     'timestamp': '2024-09-23T13:27:35.140533Z',
#     'free_bikes': 14,
#     'empty_slots': 9,
#     'extra': {'uid': '0089',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097684,
#      'slots': 24,
#      'normal_bikes': 10,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': '4ac99b928a91d8ccb785c9d0b805adb6',
#     'name': '10th & Kingsway',
#     'latitude': 49.261973,
#     'longitude': -123.09725,
#     'timestamp': '2024-09-23T13:27:35.145046Z',
#     'free_bikes': 3,
#     'empty_slots': 17,
#     'extra': {'uid': '0186',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097497,
#      'slots': 20,
#      'normal_bikes': 2,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '4cb84c9a3743287019ae00ceef9a1cd3',
#     'name': '10th & Oak',
#     'latitude': 49.262255,
#     'longitude': -123.126217,
#     'timestamp': '2024-09-23T13:27:35.141765Z',
#     'free_bikes': 10,
#     'empty_slots': 17,
#     'extra': {'uid': '0112',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097519,
#      'slots': 30,
#      'normal_bikes': 3,
#      'ebikes': 7,
#      'has_ebikes': True}},
#    {'id': '4e8fdc99e77ba1b70d90e124a704d0c1',
#     'name': 'Hawks & Union',
#     'latitude': 49.277333,
#     'longitude': -123.087359,
#     'timestamp': '2024-09-23T13:27:35.162401Z',
#     'free_bikes': 7,
#     'empty_slots': 9,
#     'extra': {'uid': '0219',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097517,
#      'slots': 16,
#      'normal_bikes': 7,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '4f6ebf2026d540ffe40e29a80138ad5e',
#     'name': 'Marinaside & Cooperage',
#     'latitude': 49.273833,
#     'longitude': -123.114373,
#     'timestamp': '2024-09-23T13:27:35.131298Z',
#     'free_bikes': 26,
#     'empty_slots': 0,
#     'extra': {'uid': '0057',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097697,
#      'slots': 26,
#      'normal_bikes': 24,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '5105df3dd0daf4c26980f4134f61e5cc',
#     'name': 'Alberni & Jervis',
#     'latitude': 49.28763,
#     'longitude': -123.127245,
#     'timestamp': '2024-09-23T13:27:35.161821Z',
#     'free_bikes': 13,
#     'empty_slots': 7,
#     'extra': {'uid': '0207',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097989,
#      'slots': 20,
#      'normal_bikes': 11,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '51e4d3731aebbf9c3186f310a08de6c8',
#     'name': '7th & Arbutus',
#     'latitude': 49.265605,
#     'longitude': -123.152566,
#     'timestamp': '2024-09-23T13:27:35.141622Z',
#     'free_bikes': 2,
#     'empty_slots': 14,
#     'extra': {'uid': '0109',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097875,
#      'slots': 16,
#      'normal_bikes': 0,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '521c2122c791ed038168c3b8ff24061b',
#     'name': '14th & Ontario',
#     'latitude': 49.25849,
#     'longitude': -123.104799,
#     'timestamp': '2024-09-23T13:27:35.142649Z',
#     'free_bikes': 7,
#     'empty_slots': 9,
#     'extra': {'uid': '0132',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097969,
#      'slots': 16,
#      'normal_bikes': 6,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '539432ded28d137406b01b3aa9622ac3',
#     'name': 'Cambie & Cordova',
#     'latitude': 49.283668,
#     'longitude': -123.109002,
#     'timestamp': '2024-09-23T13:27:35.144317Z',
#     'free_bikes': 0,
#     'empty_slots': 18,
#     'extra': {'uid': '0169',
#      'renting': False,
#      'returning': False,
#      'last_updated': 0,
#      'slots': 18,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '549f00f6039e8bb702a00dcca08a8ed0',
#     'name': 'King Edward & Cambie',
#     'latitude': 49.249184,
#     'longitude': -123.116141,
#     'timestamp': '2024-09-23T13:27:35.253623Z',
#     'free_bikes': 13,
#     'empty_slots': 2,
#     'extra': {'uid': '0524',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097897,
#      'slots': 18,
#      'normal_bikes': 0,
#      'ebikes': 13,
#      'has_ebikes': True}},
#    {'id': '5699b40126e10c2f68eefc3eb18ff3a1',
#     'name': '1st & Fir',
#     'latitude': 49.270783,
#     'longitude': -123.141564,
#     'timestamp': '2024-09-23T13:27:35.234887Z',
#     'free_bikes': 6,
#     'empty_slots': 10,
#     'extra': {'uid': '0315',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097972,
#      'slots': 20,
#      'normal_bikes': 6,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '56fef9ba0af67a4ff3e661a8e02c0b08',
#     'name': 'Arbutus & 16th',
#     'latitude': 49.257654,
#     'longitude': -123.153212,
#     'timestamp': '2024-09-23T13:27:35.141874Z',
#     'free_bikes': 15,
#     'empty_slots': 25,
#     'extra': {'uid': '0113',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097729,
#      'slots': 40,
#      'normal_bikes': 13,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '5726de7c5646b82f7aaeafba50aee03e',
#     'name': 'War Memorial Gym',
#     'latitude': 49.2665793,
#     'longitude': -123.2485487,
#     'timestamp': '2024-09-23T13:27:35.604502Z',
#     'free_bikes': 4,
#     'empty_slots': 24,
#     'extra': {'uid': '2143',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097473,
#      'slots': 28,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '57d39a680c9407cda0fb4de6d9c55138',
#     'name': '28th & Willow',
#     'latitude': 49.246243,
#     'longitude': -123.124373,
#     'timestamp': '2024-09-23T13:27:35.251207Z',
#     'free_bikes': 9,
#     'empty_slots': 10,
#     'extra': {'uid': '0505',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097856,
#      'slots': 20,
#      'normal_bikes': 6,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '57e928d8c30fab0ebffb3ede850f89d6',
#     'name': 'Arbutus Greenway & Fir',
#     'latitude': 49.266774,
#     'longitude': -123.141135,
#     'timestamp': '2024-09-23T13:27:35.143779Z',
#     'free_bikes': 5,
#     'empty_slots': 10,
#     'extra': {'uid': '0153',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097954,
#      'slots': 16,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '58345bb719f4e570ed4edc9dfa6a68a2',
#     'name': 'West Mall Swing Space Building',
#     'latitude': 49.263073,
#     'longitude': -123.254307,
#     'timestamp': '2024-09-23T13:27:35.604134Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '2114',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097664,
#      'slots': 20,
#      'normal_bikes': 2,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '58a026f0c506caec20697a4f90538450',
#     'name': 'McLean & Pender',
#     'latitude': 49.280427,
#     'longitude': -123.074082,
#     'timestamp': '2024-09-23T13:27:35.162774Z',
#     'free_bikes': 1,
#     'empty_slots': 15,
#     'extra': {'uid': '0225',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097639,
#      'slots': 16,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '5a34495280727a5b50b9aa41e14e9a16',
#     'name': 'Bute & Barclay',
#     'latitude': 49.284893,
#     'longitude': -123.128685,
#     'timestamp': '2024-09-23T13:27:35.234426Z',
#     'free_bikes': 17,
#     'empty_slots': 13,
#     'extra': {'uid': '0300',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097979,
#      'slots': 30,
#      'normal_bikes': 15,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '5ba6e9725b1b0ee8cd25df976e47726b',
#     'name': 'Balsam & Cornwall',
#     'latitude': 49.273011,
#     'longitude': -123.159663,
#     'timestamp': '2024-09-23T13:27:35.248799Z',
#     'free_bikes': 0,
#     'empty_slots': 20,
#     'extra': {'uid': '0470',
#      'renting': False,
#      'returning': False,
#      'last_updated': 1725041440,
#      'slots': 20,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '5de0fe55497681d4cc9dd25509cf51ab',
#     'name': 'Hastings & Broughton',
#     'latitude': 49.290112,
#     'longitude': -123.127062,
#     'timestamp': '2024-09-23T13:27:35.130296Z',
#     'free_bikes': 17,
#     'empty_slots': 6,
#     'extra': {'uid': '0035',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097665,
#      'slots': 24,
#      'normal_bikes': 14,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '5f45325fdd6334a4c0d3b62853b19fa6',
#     'name': 'Seymour & Cordova',
#     'latitude': 49.28512,
#     'longitude': -123.11242,
#     'timestamp': '2024-09-23T13:27:35.234554Z',
#     'free_bikes': 12,
#     'empty_slots': 5,
#     'extra': {'uid': '0308',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097972,
#      'slots': 19,
#      'normal_bikes': 12,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '5fc29e0ac42c11abb45bf12aaeb925bd',
#     'name': 'Alder & 11th',
#     'latitude': 49.261742,
#     'longitude': -123.13148,
#     'timestamp': '2024-09-23T13:27:35.144244Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '0166',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097806,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 5,
#      'has_ebikes': True}},
#    {'id': '61901a235d4cfceb7f8f2c3888b98617',
#     'name': '10th & Columbia',
#     'latitude': 49.262206,
#     'longitude': -123.109091,
#     'timestamp': '2024-09-23T13:27:35.144538Z',
#     'free_bikes': 2,
#     'empty_slots': 12,
#     'extra': {'uid': '0172',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097465,
#      'slots': 14,
#      'normal_bikes': 2,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '625a2ad202275c8e2be3ce868e85b105',
#     'name': 'Heather & 14th',
#     'latitude': 49.259183,
#     'longitude': -123.120126,
#     'timestamp': '2024-09-23T13:27:35.141405Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0106',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097971,
#      'slots': 18,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '62a202eb98c0a4b09ba6746f5ee94ab3',
#     'name': 'Commercial & 20th',
#     'latitude': 49.252656,
#     'longitude': -123.067965,
#     'timestamp': '2024-09-23T13:27:35.234947Z',
#     'free_bikes': 5,
#     'empty_slots': 15,
#     'extra': {'uid': '0352',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097835,
#      'slots': 20,
#      'normal_bikes': 2,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '6526a2eb3832f9ba0224d237e901ea5b',
#     'name': 'Kitsilano Beach Park',
#     'latitude': 49.273355,
#     'longitude': -123.154493,
#     'timestamp': '2024-09-23T13:27:35.143854Z',
#     'free_bikes': 34,
#     'empty_slots': 2,
#     'extra': {'uid': '0154',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097750,
#      'slots': 36,
#      'normal_bikes': 28,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': '6620c54bd6b3a79800b2b67e999b24d0',
#     'name': 'Rolston & Granville',
#     'latitude': 49.274232,
#     'longitude': -123.129998,
#     'timestamp': '2024-09-23T13:27:35.234827Z',
#     'free_bikes': 11,
#     'empty_slots': 7,
#     'extra': {'uid': '0314',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097632,
#      'slots': 16,
#      'normal_bikes': 8,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '664502c28e8147615f17b8ea355f40d0',
#     'name': 'Cordova & Bute',
#     'latitude': 49.289124,
#     'longitude': -123.12196,
#     'timestamp': '2024-09-23T13:27:35.130205Z',
#     'free_bikes': 2,
#     'empty_slots': 12,
#     'extra': {'uid': '0034',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097767,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '66f873d641d448bd1572ab086665a458',
#     'name': '12th & Yukon (City Hall)',
#     'latitude': 49.260599,
#     'longitude': -123.113504,
#     'timestamp': '2024-09-23T13:27:35.128380Z',
#     'free_bikes': 5,
#     'empty_slots': 11,
#     'extra': {'uid': '0007',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097636,
#      'slots': 16,
#      'normal_bikes': 4,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '671ce9e4a92063620f772d2c57f0f3ab',
#     'name': 'Blenheim & 4th',
#     'latitude': 49.268837,
#     'longitude': -123.177633,
#     'timestamp': '2024-09-23T13:27:35.235416Z',
#     'free_bikes': 9,
#     'empty_slots': 13,
#     'extra': {'uid': '0431',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097972,
#      'slots': 23,
#      'normal_bikes': 9,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '680b1ddfd50c4397b365c9c00f09b0d1',
#     'name': 'Wylie & 2nd',
#     'latitude': 49.267725,
#     'longitude': -123.11311,
#     'timestamp': '2024-09-23T13:27:35.143366Z',
#     'free_bikes': 16,
#     'empty_slots': 2,
#     'extra': {'uid': '0144',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097650,
#      'slots': 18,
#      'normal_bikes': 14,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '686b314a6c3348efd2297d6b3dfed1a7',
#     'name': 'Thurlow & Pendrell',
#     'latitude': 49.280881,
#     'longitude': -123.130672,
#     'timestamp': '2024-09-23T13:27:35.142436Z',
#     'free_bikes': 9,
#     'empty_slots': 7,
#     'extra': {'uid': '0126',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097954,
#      'slots': 16,
#      'normal_bikes': 9,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '686c0fdb962e26e274d81fc286c010dd',
#     'name': '14th & Cambie',
#     'latitude': 49.258763,
#     'longitude': -123.115392,
#     'timestamp': '2024-09-23T13:27:35.131838Z',
#     'free_bikes': 1,
#     'empty_slots': 10,
#     'extra': {'uid': '0072',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097870,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '6993b3dbb0758927967592ea612a2b1e',
#     'name': 'Granville & Georgia',
#     'latitude': 49.282409,
#     'longitude': -123.118541,
#     'timestamp': '2024-09-23T13:27:35.128971Z',
#     'free_bikes': 0,
#     'empty_slots': 20,
#     'extra': {'uid': '0015',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727049847,
#      'slots': 20,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '6b1622540fe5c85d365754dd8c20bf0c',
#     'name': 'Grant & Commercial',
#     'latitude': 49.271377,
#     'longitude': -123.069416,
#     'timestamp': '2024-09-23T13:27:35.183825Z',
#     'free_bikes': 4,
#     'empty_slots': 10,
#     'extra': {'uid': '0239',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097598,
#      'slots': 14,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '6c0de983fb47a3439a9e3c36a3d15804',
#     'name': '8th & Ontario',
#     'latitude': 49.263837,
#     'longitude': -123.105173,
#     'timestamp': '2024-09-23T13:27:35.141478Z',
#     'free_bikes': 10,
#     'empty_slots': 6,
#     'extra': {'uid': '0107',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097985,
#      'slots': 16,
#      'normal_bikes': 7,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': '6c24a62b5ee0a2a8014eb0dfb6d40025',
#     'name': 'Hornby & Nelson',
#     'latitude': 49.28062,
#     'longitude': -123.12482,
#     'timestamp': '2024-09-23T13:27:35.130452Z',
#     'free_bikes': 3,
#     'empty_slots': 14,
#     'extra': {'uid': '0037',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097985,
#      'slots': 18,
#      'normal_bikes': 1,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '6c7fb9043e6df5a4cc50404581a947b9',
#     'name': "šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery",
#     'latitude': 49.283227,
#     'longitude': -123.120523,
#     'timestamp': '2024-09-23T13:27:35.140901Z',
#     'free_bikes': 2,
#     'empty_slots': 20,
#     'extra': {'uid': '0099',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097957,
#      'slots': 28,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '6d42fa40360f9a6b2bf641c7b8bb2862',
#     'name': 'Dunsmuir & Beatty',
#     'latitude': 49.279764,
#     'longitude': -123.110154,
#     'timestamp': '2024-09-23T13:27:35.128227Z',
#     'free_bikes': 17,
#     'empty_slots': 7,
#     'extra': {'uid': '0005',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097957,
#      'slots': 26,
#      'normal_bikes': 16,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '6ddeafa873279951630a00191333c45d',
#     'name': 'Robson & Granville',
#     'latitude': 49.281506,
#     'longitude': -123.120101,
#     'timestamp': '2024-09-23T13:27:35.131449Z',
#     'free_bikes': 9,
#     'empty_slots': 14,
#     'extra': {'uid': '0063',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727096840,
#      'slots': 24,
#      'normal_bikes': 9,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '6eaa02e5bcf78db5386683d38fa2dabd',
#     'name': '4th & Commercial',
#     'latitude': 49.266969,
#     'longitude': -123.069936,
#     'timestamp': '2024-09-23T13:27:35.206439Z',
#     'free_bikes': 5,
#     'empty_slots': 9,
#     'extra': {'uid': '0241',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097914,
#      'slots': 14,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '707c1c54e0278fbae5d0ae3c42a25b71',
#     'name': '8th & Scotia',
#     'latitude': 49.263635,
#     'longitude': -123.099236,
#     'timestamp': '2024-09-23T13:27:35.161756Z',
#     'free_bikes': 5,
#     'empty_slots': 4,
#     'extra': {'uid': '0206',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097931,
#      'slots': 12,
#      'normal_bikes': 4,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': '7181df50ee1d1a05559399211382b7c8',
#     'name': 'Homer & Robson (Vancouver Public Library)',
#     'latitude': 49.279739,
#     'longitude': -123.116251,
#     'timestamp': '2024-09-23T13:27:35.129602Z',
#     'free_bikes': 4,
#     'empty_slots': 16,
#     'extra': {'uid': '0025',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097957,
#      'slots': 20,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '71c064fa93cab5f0b7306e6c923b77c4',
#     'name': '7th & Granville',
#     'latitude': 49.2653,
#     'longitude': -123.13811,
#     'timestamp': '2024-09-23T13:27:35.131688Z',
#     'free_bikes': 2,
#     'empty_slots': 11,
#     'extra': {'uid': '0069',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097794,
#      'slots': 14,
#      'normal_bikes': 0,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '72c1049dfbbde7c24ec45c14f1a5ee85',
#     'name': 'Harwood & Bute',
#     'latitude': 49.28026,
#     'longitude': -123.135244,
#     'timestamp': '2024-09-23T13:27:35.140462Z',
#     'free_bikes': 4,
#     'empty_slots': 16,
#     'extra': {'uid': '0088',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097975,
#      'slots': 20,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': '73f388336d879bedc962cd412eb0296e',
#     'name': 'Creekside Park North',
#     'latitude': 49.2756,
#     'longitude': -123.102661,
#     'timestamp': '2024-09-23T13:27:35.143507Z',
#     'free_bikes': 14,
#     'empty_slots': 3,
#     'extra': {'uid': '0148',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097978,
#      'slots': 18,
#      'normal_bikes': 12,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': '77163e893653b88926e07fd6b9f688da',
#     'name': 'Nicola & Robson',
#     'latitude': 49.2885056,
#     'longitude': -123.1312375,
#     'timestamp': '2024-09-23T13:27:35.140757Z',
#     'free_bikes': 14,
#     'empty_slots': 3,
#     'extra': {'uid': '0096',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097818,
#      'slots': 18,
#      'normal_bikes': 8,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': '797ff1725f8d2b18337de51e240ff60d',
#     'name': '10th & Commercial',
#     'latitude': 49.261403,
#     'longitude': -123.070102,
#     'timestamp': '2024-09-23T13:27:35.206651Z',
#     'free_bikes': 0,
#     'empty_slots': 26,
#     'extra': {'uid': '0244',
# ...
#     'longitude': -123.065925,
#     'timestamp': '2024-09-23T13:27:35.233275Z',
#     'free_bikes': 9,
#     'empty_slots': 7,
#     'extra': {'uid': '0273',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097933,
#      'slots': 16,
#      'normal_bikes': 7,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': 'd8c4fe5e09b6f010fbaa85cc7302d66b',
#     'name': 'Heather & 29th',
#     'latitude': 49.245535,
#     'longitude': -123.120496,
#     'timestamp': '2024-09-23T13:27:35.252241Z',
#     'free_bikes': 9,
#     'empty_slots': 13,
#     'extra': {'uid': '0516',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097199,
#      'slots': 22,
#      'normal_bikes': 9,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'da8b6e94f90ad41a3f8de10596992372',
#     'name': 'Jervis & Robson',
#     'latitude': 49.28691,
#     'longitude': -123.128818,
#     'timestamp': '2024-09-23T13:27:35.234617Z',
#     'free_bikes': 6,
#     'empty_slots': 13,
#     'extra': {'uid': '0310',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097840,
#      'slots': 20,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': 'db1e56a71a3279f51301d732ee5a055b',
#     'name': 'IK Barber Learning Centre',
#     'latitude': 49.267561,
#     'longitude': -123.252261,
#     'timestamp': '2024-09-23T13:27:35.604367Z',
#     'free_bikes': 1,
#     'empty_slots': 18,
#     'extra': {'uid': '2132',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727060760,
#      'slots': 20,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'db51c556fe50ec1deefbc9697c70cb51',
#     'name': 'Granville Island',
#     'latitude': 49.27029,
#     'longitude': -123.135025,
#     'timestamp': '2024-09-23T13:27:35.145188Z',
#     'free_bikes': 10,
#     'empty_slots': 22,
#     'extra': {'uid': '0189',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097835,
#      'slots': 32,
#      'normal_bikes': 9,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'dcf3d5c9f1b3a46f0ef2eb2247931f89',
#     'name': '6th & Prince Edward',
#     'latitude': 49.265242,
#     'longitude': -123.095577,
#     'timestamp': '2024-09-23T13:27:35.234299Z',
#     'free_bikes': 5,
#     'empty_slots': 11,
#     'extra': {'uid': '0297',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097981,
#      'slots': 16,
#      'normal_bikes': 2,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': 'df5ab349a7a85d4b10da4cc3ec65c607',
#     'name': 'Broughton & Davie',
#     'latitude': 49.283749,
#     'longitude': -123.136133,
#     'timestamp': '2024-09-23T13:27:35.140386Z',
#     'free_bikes': 13,
#     'empty_slots': 1,
#     'extra': {'uid': '0087',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097550,
#      'slots': 22,
#      'normal_bikes': 3,
#      'ebikes': 10,
#      'has_ebikes': True}},
#    {'id': 'e02dd224b0177c65418bcb3f72d2f77d',
#     'name': 'Adanac & Lakewood',
#     'latitude': 49.27751,
#     'longitude': -123.061429,
#     'timestamp': '2024-09-23T13:27:35.603257Z',
#     'free_bikes': 7,
#     'empty_slots': 12,
#     'extra': {'uid': '0617',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097864,
#      'slots': 20,
#      'normal_bikes': 0,
#      'ebikes': 7,
#      'has_ebikes': True}},
#    {'id': 'e0318460138ffbf4692005d5b5a9f900',
#     'name': 'Cypress & 10th',
#     'latitude': 49.262944,
#     'longitude': -123.148109,
#     'timestamp': '2024-09-23T13:27:35.131632Z',
#     'free_bikes': 1,
#     'empty_slots': 13,
#     'extra': {'uid': '0068',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097641,
#      'slots': 14,
#      'normal_bikes': 0,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'e0f30136c6ec6330f93d6c2c8463a0f4',
#     'name': 'Thunderbird Parkade',
#     'latitude': 49.261655,
#     'longitude': -123.241924,
#     'timestamp': '2024-09-23T13:27:35.604671Z',
#     'free_bikes': 0,
#     'empty_slots': 18,
#     'extra': {'uid': '2157',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097498,
#      'slots': 18,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'e12234b6f1299d178f34bffaca92f043',
#     'name': 'Burrard Station (Melville & Dunsmuir)',
#     'latitude': 49.285871,
#     'longitude': -123.12105,
#     'timestamp': '2024-09-23T13:27:35.128041Z',
#     'free_bikes': 6,
#     'empty_slots': 22,
#     'extra': {'uid': '0002',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097565,
#      'slots': 28,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': 'e1432b72df561a1df34290679ec9c773',
#     'name': '22nd & Cambie',
#     'latitude': 49.251358,
#     'longitude': -123.115637,
#     'timestamp': '2024-09-23T13:27:35.256603Z',
#     'free_bikes': 5,
#     'empty_slots': 9,
#     'extra': {'uid': '0532',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097766,
#      'slots': 14,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'e1ff428dadc7c32141b9d89a7b56728a',
#     'name': 'Glen & Broadway',
#     'latitude': 49.262242,
#     'longitude': -123.081459,
#     'timestamp': '2024-09-23T13:27:35.206788Z',
#     'free_bikes': 9,
#     'empty_slots': 9,
#     'extra': {'uid': '0246',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097536,
#      'slots': 18,
#      'normal_bikes': 8,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'e3d32ad772a5898c3b96c4d23d2cd542',
#     'name': 'Stanley Park - Totem Poles',
#     'latitude': 49.298657,
#     'longitude': -123.121176,
#     'timestamp': '2024-09-23T13:27:35.141326Z',
#     'free_bikes': 13,
#     'empty_slots': 5,
#     'extra': {'uid': '0105',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097812,
#      'slots': 20,
#      'normal_bikes': 12,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'e75e83499d3fa2e174dc2a8ffd238119',
#     'name': 'Davie & Beach',
#     'latitude': 49.287528,
#     'longitude': -123.142139,
#     'timestamp': '2024-09-23T13:27:35.129893Z',
#     'free_bikes': 29,
#     'empty_slots': 1,
#     'extra': {'uid': '0028',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097952,
#      'slots': 30,
#      'normal_bikes': 25,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': 'e7bf01431a6982f032996ad50a9e5bd7',
#     'name': 'Pender & Gore',
#     'latitude': 49.280284,
#     'longitude': -123.097052,
#     'timestamp': '2024-09-23T13:27:35.162143Z',
#     'free_bikes': 10,
#     'empty_slots': 4,
#     'extra': {'uid': '0213',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097877,
#      'slots': 14,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'e9b37f2d9b7b2e2e3ade73f13acb69b2',
#     'name': 'Richards & Davie',
#     'latitude': 49.275683,
#     'longitude': -123.124388,
#     'timestamp': '2024-09-23T13:27:35.136211Z',
#     'free_bikes': 2,
#     'empty_slots': 11,
#     'extra': {'uid': '0082',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097706,
#      'slots': 14,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'e9c4bd1fffbb1e5b058b8ea15f7307f6',
#     'name': 'Pender & Commercial',
#     'latitude': 49.280332,
#     'longitude': -123.070068,
#     'timestamp': '2024-09-23T13:27:35.162690Z',
#     'free_bikes': 5,
#     'empty_slots': 11,
#     'extra': {'uid': '0224',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097594,
#      'slots': 16,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'ea9485fcdce0611243474d000e4ad248',
#     'name': '18th & Cambie',
#     'latitude': 49.254818,
#     'longitude': -123.114785,
#     'timestamp': '2024-09-23T13:27:35.256334Z',
#     'free_bikes': 3,
#     'empty_slots': 21,
#     'extra': {'uid': '0531',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097548,
#      'slots': 24,
#      'normal_bikes': 2,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'eb786a8088b649c829d1d139e205befb',
#     'name': 'McNicoll & Arbutus',
#     'latitude': 49.276293,
#     'longitude': -123.150934,
#     'timestamp': '2024-09-23T13:27:35.143928Z',
#     'free_bikes': 15,
#     'empty_slots': 15,
#     'extra': {'uid': '0155',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097865,
#      'slots': 30,
#      'normal_bikes': 12,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': 'ebc551adb0fc1a684f4080e4954a9ba4',
#     'name': '2nd & Commercial',
#     'latitude': 49.268616,
#     'longitude': -123.069908,
#     'timestamp': '2024-09-23T13:27:35.192650Z',
#     'free_bikes': 11,
#     'empty_slots': 11,
#     'extra': {'uid': '0240',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097580,
#      'slots': 22,
#      'normal_bikes': 9,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': 'ee620d77724c8993b0d366e7ec655b64',
#     'name': 'Wesbrook Village - Berton & Shrum',
#     'latitude': 49.25478,
#     'longitude': -123.23621,
#     'timestamp': '2024-09-23T13:27:35.604742Z',
#     'free_bikes': 13,
#     'empty_slots': 15,
#     'extra': {'uid': '2252',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097758,
#      'slots': 28,
#      'normal_bikes': 7,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': 'efa947b901a2cf85b58320b3ad26a2fe',
#     'name': 'Chilco & Robson',
#     'latitude': 49.293257,
#     'longitude': -123.138563,
#     'timestamp': '2024-09-23T13:27:35.140684Z',
#     'free_bikes': 6,
#     'empty_slots': 10,
#     'extra': {'uid': '0093',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097569,
#      'slots': 16,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True}},
#    {'id': 'f1ca711137cde59e824167a4274df888',
#     'name': 'Keefer & Columbia',
#     'latitude': 49.279342,
#     'longitude': -123.101822,
#     'timestamp': '2024-09-23T13:27:35.131248Z',
#     'free_bikes': 7,
#     'empty_slots': 7,
#     'extra': {'uid': '0055',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097879,
#      'slots': 14,
#      'normal_bikes': 6,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'f3708906ec71348f5a42579fede36a0d',
#     'name': 'Rogers Tower',
#     'latitude': 49.288682,
#     'longitude': -123.11818,
#     'timestamp': '2024-09-23T13:27:35.161469Z',
#     'free_bikes': 5,
#     'empty_slots': 6,
#     'extra': {'uid': '0201',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097309,
#      'slots': 18,
#      'normal_bikes': 1,
#      'ebikes': 4,
#      'has_ebikes': True}},
#    {'id': 'f387ec226c432c5c054e3d3616d90501',
#     'name': 'Woodland & Graveley',
#     'latitude': 49.270684,
#     'longitude': -123.073562,
#     'timestamp': '2024-09-23T13:27:35.232343Z',
#     'free_bikes': 4,
#     'empty_slots': 8,
#     'extra': {'uid': '0252',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097879,
#      'slots': 12,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'f38bac9712f3beee2149ba2a97048878',
#     'name': 'Cardero & Bayshore',
#     'latitude': 49.291597,
#     'longitude': -123.129158,
#     'timestamp': '2024-09-23T13:27:35.161207Z',
#     'free_bikes': 14,
#     'empty_slots': 6,
#     'extra': {'uid': '0200',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097884,
#      'slots': 20,
#      'normal_bikes': 11,
#      'ebikes': 3,
#      'has_ebikes': True}},
#    {'id': 'f5e8fa1fc4252bda2f93dd27ed2d603f',
#     'name': 'Nelson & Denman',
#     'latitude': 49.2890705989865,
#     'longitude': -123.138407369468,
#     'timestamp': '2024-09-23T13:27:35.234763Z',
#     'free_bikes': 10,
#     'empty_slots': 8,
#     'extra': {'uid': '0313',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097989,
#      'slots': 18,
#      'normal_bikes': 9,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'f62bc2bfe9a0a563d5b6745ce6d962ba',
#     'name': '8th & Fraser',
#     'latitude': 49.263382,
#     'longitude': -123.088837,
#     'timestamp': '2024-09-23T13:27:35.232923Z',
#     'free_bikes': 1,
#     'empty_slots': 15,
#     'extra': {'uid': '0261',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097963,
#      'slots': 16,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'f90ed7ad754ec04b7852941a480a4c77',
#     'name': 'Balaclava & 6th',
#     'latitude': 49.266924,
#     'longitude': -123.173849,
#     'timestamp': '2024-09-23T13:27:35.235533Z',
#     'free_bikes': 6,
#     'empty_slots': 10,
#     'extra': {'uid': '0443',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097825,
#      'slots': 16,
#      'normal_bikes': 6,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'f97d5bf41f35aa181288429fb52e3488',
#     'name': 'Cambie & Water',
#     'latitude': 49.284605,
#     'longitude': -123.108662,
#     'timestamp': '2024-09-23T13:27:35.131090Z',
#     'free_bikes': 12,
#     'empty_slots': 19,
#     'extra': {'uid': '0052',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097983,
#      'slots': 32,
#      'normal_bikes': 11,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'fad9ebcf614dd1a72593a34072ff76f8',
#     'name': 'Helmcken & Burrard',
#     'latitude': 49.279938,
#     'longitude': -123.127478,
#     'timestamp': '2024-09-23T13:27:35.130521Z',
#     'free_bikes': 5,
#     'empty_slots': 9,
#     'extra': {'uid': '0039',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097969,
#      'slots': 15,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'fbb1d30d7f30b049873f5be5688563d4',
#     'name': 'Hornby & Pender',
#     'latitude': 49.28602,
#     'longitude': -123.116624,
#     'timestamp': '2024-09-23T13:27:35.129530Z',
#     'free_bikes': 18,
#     'empty_slots': 3,
#     'extra': {'uid': '0024',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097869,
#      'slots': 22,
#      'normal_bikes': 17,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'fbb4c06b719596c21f91fd51ef6d4710',
#     'name': '7th & Heather',
#     'latitude': 49.265089,
#     'longitude': -123.119425,
#     'timestamp': '2024-09-23T13:27:35.136064Z',
#     'free_bikes': 11,
#     'empty_slots': 7,
#     'extra': {'uid': '0081',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097612,
#      'slots': 18,
#      'normal_bikes': 11,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'fe0c57d04d6e682d284d501446095fc9',
#     'name': 'Union & Dunlevy',
#     'latitude': 49.277595,
#     'longitude': -123.09583,
#     'timestamp': '2024-09-23T13:27:35.162078Z',
#     'free_bikes': 12,
#     'empty_slots': 4,
#     'extra': {'uid': '0212',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097955,
#      'slots': 16,
#      'normal_bikes': 12,
#      'ebikes': 0,
#      'has_ebikes': True}},
#    {'id': 'fedff7a263c182df94bda7307059cc52',
#     'name': 'Richards & Helmcken',
#     'latitude': 49.277141,
#     'longitude': -123.122589,
#     'timestamp': '2024-09-23T13:27:35.143007Z',
#     'free_bikes': 10,
#     'empty_slots': 7,
#     'extra': {'uid': '0138',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097695,
#      'slots': 18,
#      'normal_bikes': 4,
#      'ebikes': 6,
#      'has_ebikes': True}},
#    {'id': 'fef69fb400210d861107a61db954d037',
#     'name': 'Keefer & Abbott',
#     'latitude': 49.279821,
#     'longitude': -123.10802,
#     'timestamp': '2024-09-23T13:27:35.131142Z',
#     'free_bikes': 25,
#     'empty_slots': 3,
#     'extra': {'uid': '0053',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097993,
#      'slots': 28,
#      'normal_bikes': 24,
#      'ebikes': 1,
#      'has_ebikes': True}},
#    {'id': 'fffd87607aaae16fbb1f71615cbe7d17',
#     'name': '8th & Prince Edward',
#     'latitude': 49.263518,
#     'longitude': -123.09568,
#     'timestamp': '2024-09-23T13:27:35.232993Z',
#     'free_bikes': 4,
#     'empty_slots': 13,
#     'extra': {'uid': '0262',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1727097957,
#      'slots': 18,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True}}]}}

# %%
from pandas import json_normalize

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
van_network_stations = pd.json_normalize(data=data1, record_path=['network', 'stations'])
van_network_stations = van_network_stations[['free_bikes', 'id', 'longitude', 'latitude']]
van_network_stations
# Out:
#      free_bikes                                id   longitude   latitude
# 0            10  00fa94ad698dc4a9e4d708d6fd32f294 -123.140713  49.291909
# 1             7  012d3e06901cc222b1c2cf0a2ace3a29 -123.093060  49.262321
# 2             4  029a505bd4422a1afd127987757f71a6 -123.071865  49.275882
# 3            17  0438114d2e6b96118de69bc9775bb21e -123.142135  49.288030
# 4             6  0459b7e93703980b853cd65a9dc60596 -123.092723  49.273777
# ..          ...                               ...         ...        ...
# 251          11  fbb4c06b719596c21f91fd51ef6d4710 -123.119425  49.265089
# 252          12  fe0c57d04d6e682d284d501446095fc9 -123.095830  49.277595
# 253          10  fedff7a263c182df94bda7307059cc52 -123.122589  49.277141
# 254          25  fef69fb400210d861107a61db954d037 -123.108020  49.279821
# 255           4  fffd87607aaae16fbb1f71615cbe7d17 -123.095680  49.263518
#
# [256 rows x 4 columns]

# %%
van_network_stations.to_csv('../data/van_network_stations.csv')
